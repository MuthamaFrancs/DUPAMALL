# %%
'''
name: F R A N C I S   M U S A U
date: 17th Sep 2025
title:Web Scraping using BeautifulSoup, Requests and Pandas
description: extracting data using web scraping.Automating data collection using
python and libraries like BeautifulSoup, Pandas and Requests.
'''
# Out:
# '\nname: F R A N C I S   M U S A U\ndate: 17th Sep 2025\ntitle:Web Scraping using BeautifulSoup, Requests and Pandas\ndescription:\n\n'

# %%
#importing libraries needed for web scrapping.
from bs4 import BeautifulSoup
import requests
import pandas as pd
from google.colab import files

# %%
url='https://www.scrapethissite.com/pages/forms/'
page_response=requests.get(url)
print(page_response)
# Out:
# <Response [200]>

# %%
#checking data by extracting a table with the scores.
#create an object of the beautiful soup class - soup() from where I can access the page's elements eg. title, table etc.
soup=BeautifulSoup(page_response.text,"html")
print(soup.title)
# Out:
# <title>Hockey Teams: Forms, Searching and Pagination | Scrape This Site | A public sandbox for learning web scraping</title>

# %%
#leets extract the table W Hockey Scores now...
table = soup.find('table', class_='table')
#print(table)

# %%
#Exteacting column headings
table_headings = [th.get_text(strip=True) for th in table.find_all("th")]
print(table_headings)
# Out:
# ['Team Name', 'Year', 'Wins', 'Losses', 'OT Losses', 'Win %', 'Goals For (GF)', 'Goals Against (GA)', '+ / -']

# %%
#Exporting the colum heads into a dataframe
df = pd.DataFrame(columns=table_headings)
df
# Out:
# Empty DataFrame
# Columns: [Team Name, Year, Wins, Losses, OT Losses, Win %, Goals For (GF), Goals Against (GA), + / -]
# Index: []

# %%
#extracting data row by row
table_data = table.find_all('tr')

##added next line of code after inspection
print('Rows found: ',len(rows))

for row in table_data:
    row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data]
    #print(individual_row_data)

    if len(individual_row_data):
        df.loc[len(df)] = individual_row_data
# Out:
# Rows found:  0

# %%
#Exporting the data into a CSV
df.to_csv('hockey_teams.csv', index=False)

#the index=false removes the first column of index 0,1,2..
#files.download('hockey_teams.csv') df.to_csv(r'./Hockey.csv')

# %%
#inspecting the df
df_csv = pd.read_csv("hockey_teams.csv")
print(df_csv.head())
print(df_csv.shape)
df
#print(df.info)
# Out:
#             Team Name  Year  Wins  Losses  OT Losses  Win %  Goals For (GF)  \
# 0       Boston Bruins  1990    44      24        NaN  0.550             299
# 1      Buffalo Sabres  1990    31      30        NaN  0.388             292
# 2      Calgary Flames  1990    46      26        NaN  0.575             344
# 3  Chicago Blackhawks  1990    49      23        NaN  0.613             284
# 4   Detroit Red Wings  1990    34      38        NaN  0.425             273
#
#    Goals Against (GA)  + / -
# 0                 264     35
# 1                 278     14
# 2                 263     81
# 3                 211     73
# 4                 298    -25
# (25, 9)
#                 Team Name  Year Wins Losses OT Losses  Win % Goals For (GF)  \
# 0           Boston Bruins  1990   44     24             0.55            299
# 1          Buffalo Sabres  1990   31     30            0.388            292
# 2          Calgary Flames  1990   46     26            0.575            344
# ...
